# %%
import pandas as pd
import random
import pickle
import matplotlib.pyplot as plt

# %%
result = pd.read_parquet('data/partner_performances/235.parquet')

# %%
result['Sustained profit'] = result['Sustained profit'] * -1

# %%
plt.plot(result.index.values, result['Profit gain'], label='Profit gain')
plt.plot(result.index.values, result['Sustained profit'], label='Sustained profit')
plt.axhline(linewidth = 1, color= 'r')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
# plt.savefig('pgsp.png')
plt.show()

# %%
plt.plot(result.index.values, result['Accumulated sustained profit'], label='Accumulated sustained profit')
plt.plot(result.index.values, result['Accumulated profit gain'], label='Accumulated profit gain')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
# plt.savefig('aspapg.png')
plt.show()

# %%
# plt.plot(result.index.values, result['Accumulated sustained profit'], label='Accumulated sustained profit')
plt.plot(result.index.values, result['Accumulated profit gain'], label='Accumulated profit gain')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
# plt.savefig('apg.png')
plt.show()

# %%
plt.plot(result.index.values, result['Accumulated sustained profit'], label='Accumulated sustained profit')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
plt.savefig('asp.png')
plt.show()

# %%
plt.plot(result.index.values, result['Accumulated profit gain ratio'], label='Accumulated profit gain ratio')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
plt.savefig('apgr.png')
plt.show()
