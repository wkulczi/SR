# %%
import pandas as pd
import random
import pickle
import matplotlib.pyplot as plt

# %%
result = pd.read_parquet('data/partner_performances/235.parquet')

# %%
result['NPG'].sum()
# Out:
# -518.357814673915

# %%
result
# Out:
#     Profit gain  Sustained profit        NPG  Profit w/o optimizer  \
# 0      0.000000        -12.863354   0.000000            -12.863354
# 1    -22.358712         53.803776 -22.358712             76.162487
# 2     -8.877501         11.887571  -8.877501             20.765072
# 3    -11.700897         31.868515 -11.700897             43.569412
# 4    -25.696628         16.444816 -25.696628             42.141444
# 5     -6.735092         72.037125  -6.735092             78.772217
# 6    -61.114954         19.093700 -61.114954             80.208654
# 7    -63.861018          4.697364 -63.861018             68.558382
# 8    -50.912231          4.400904 -50.912231             55.313136
# 9    -12.465564         30.211110 -12.465564             42.676674
# 10    12.997207         82.883224  12.997207             69.886017
# 11   -16.208952         27.540638 -16.208952             43.749590
# 12   -14.298366         50.712631 -14.298366             65.010997
# 13     1.916966         28.706488   1.916966             26.789522
# 14    -3.045025         43.666899  -3.045025             46.711924
# 15    14.039873         62.767097  14.039873             48.727225
# 16   -54.398581         43.990412 -54.398581             98.388993
# 17   -48.985370         40.885124 -48.985370             89.870495
# 18   -24.051122         55.513832 -24.051122             79.564954
# 19   -17.819922        111.796864 -17.819922            129.616786
# 20   -13.276911         72.706635 -13.276911             85.983547
# 21     1.543114         39.247865   1.543114             37.704751
# 22    -0.246217         41.880601  -0.246217             42.126818
# 23   -14.917687        112.318183 -14.917687            127.235870
# 24    -8.191838         62.713710  -8.191838             70.905547
# 25   -38.087273         52.420196 -38.087273             90.507469
# 26     3.773101         44.181912   3.773101             40.408811
# 27   -15.153134         28.671191 -15.153134             43.824325
# 28     2.256696         11.169937   2.256696              8.913242
# 29   -30.090748         76.333656 -30.090748            106.424404
# 30    -1.176278          4.966340  -1.176278              6.142619
# 31     5.306301          2.254334   5.306301             -3.051966
# 32     3.478951          2.373422   3.478951             -1.105529
#
#     Accumulated profit gain  Accumulated sustained profit  \
# 0                  0.000000                    -12.863354
# 1                -22.358712                     40.940422
# 2                -31.236213                     52.827992
# 3                -42.937110                     84.696507
# 4                -68.633737                    101.141324
# 5                -75.368829                    173.178449
# 6               -136.483783                    192.272149
# 7               -200.344801                    196.969513
# 8               -251.257032                    201.370417
# 9               -263.722596                    231.581527
# 10              -250.725389                    314.464752
# 11              -266.934341                    342.005390
# 12              -281.232707                    392.718021
# 13              -279.315742                    421.424509
# 14              -282.360766                    465.091408
# 15              -268.320894                    527.858506
# 16              -322.719475                    571.848918
# 17              -371.704845                    612.734042
# 18              -395.755967                    668.247874
# 19              -413.575890                    780.044738
# 20              -426.852801                    852.751373
# 21              -425.309687                    891.999238
# 22              -425.555904                    933.879839
# 23              -440.473591                   1046.198022
# 24              -448.665429                   1108.911732
# 25              -486.752702                   1161.331928
# 26              -482.979601                   1205.513840
# 27              -498.132735                   1234.185031
# 28              -495.876040                   1245.354968
# 29              -525.966787                   1321.688624
# 30              -527.143066                   1326.654964
# 31              -521.836765                   1328.909298
# 32              -518.357815                   1331.282720
#
#     Accumulated profit w/o optimizer  Accumulated profit gain ratio
# 0                         -12.863354                            0.0
# 1                          63.299133                            0.0
# 2                          84.064205                            0.0
# 3                         127.633617                            0.0
# 4                         169.775061                            0.0
# 5                         248.547278                            0.0
# 6                         328.755932                            0.0
# 7                         397.314314                            0.0
# 8                         452.627449                            0.0
# 9                         495.304124                            0.0
# 10                        565.190141                            0.0
# 11                        608.939731                            0.0
# 12                        673.950729                            0.0
# 13                        700.740251                            0.0
# 14                        747.452175                            0.0
# 15                        796.179400                            0.0
# 16                        894.568393                            0.0
# 17                        984.438887                            0.0
# 18                       1064.003841                            0.0
# 19                       1193.620628                            0.0
# 20                       1279.604174                            0.0
# 21                       1317.308925                            0.0
# 22                       1359.435743                            0.0
# 23                       1486.671613                            0.0
# 24                       1557.577161                            0.0
# 25                       1648.084630                            0.0
# 26                       1688.493441                            0.0
# 27                       1732.317766                            0.0
# 28                       1741.231008                            0.0
# 29                       1847.655411                            0.0
# 30                       1853.798030                            0.0
# 31                       1850.746064                            0.0
# 32                       1849.640535                            0.0

# %%
plt.plot(result.index.values, result['NPG'], label='NPG')
plt.plot(result.index.values, result['Sustained profit'], label='Sustained profit')
plt.axhline(linewidth = 1, color= 'r')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
plt.show()

# %%
plt.plot(result.index.values, result['Profit gain'], label='Profit gain')
plt.plot(result.index.values, result['Sustained profit'], label='Sustained profit')
plt.axhline(linewidth = 1, color= 'r')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
plt.show()

# %%
plt.plot(result.index.values, result['Accumulated profit gain'], label='Accumulated profit gain')
plt.plot(result.index.values, result['Accumulated sustained profit'], label='Accumulated sustained profit')
plt.xlabel('Days of simulation')
plt.ylabel('EUR')
plt.legend()
plt.show()

# %%
plt.plot(result.index.values, result['Accumulated profit w/o optimizer'], label='Accumulated profit w/o optimizer')
plt.xlabel('Days of simulation')
plt.legend()
plt.show()

# %%
plt.plot(result.index.values, result['Profit w/o optimizer'], label='Profit w/o optimizer')
plt.xlabel('Days of simulation')
plt.legend()
plt.show()

# %%
result['Accumulated profit w/o optimizer'].max()
# Out:
# 1850.1340282192612
